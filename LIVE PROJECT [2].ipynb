# %%
import pandas as pd

# %%
data=pd.read_excel("C:\\Users\\mayur\\OneDrive\\Desktop\\New Microsoft Excel Worksheet.xlsx")

# %%
data.head()
# Out:
#              Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0  DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2    AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3   RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4   RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
#
#       SR  100  50  0   4s  6s
# 0  58.60   29  13  7  626   6
# 1  91.76    4   7  1  141  23
# 2  55.68    5   4  2  186   5
# 3  54.48    7  11  1  246  11
# 4  54.48    7  11  1  246  11

# %%
data["Player"].str.split("(")
# Out:
# 0      [DG Bradman , AUS)]
# 1        [HC Brook , ENG)]
# 2        [AC Voges , AUS)]
# 3       [RG Pollock , SA)]
# 4       [RG Pollock , SA)]
#               ...
# 61     [KD Walters , AUS)]
# 62    [GC Smith , ICC/SA)]
# 63    [WH Ponsford , AUS)]
# 64      [SJ McCabe , AUS)]
# 65     [DR Jardine , ENG)]
# Name: Player, Length: 66, dtype: object

# %%
data["Player"].str.split("(").str[1]
# Out:
# 0        AUS)
# 1        ENG)
# 2        AUS)
# 3         SA)
# 4         SA)
#        ...
# 61       AUS)
# 62    ICC/SA)
# 63       AUS)
# 64       AUS)
# 65       ENG)
# Name: Player, Length: 66, dtype: object

# %%
data["Player"].str.split("(").str[1].str.split(")")
# Out:
# 0        [AUS, ]
# 1        [ENG, ]
# 2        [AUS, ]
# 3         [SA, ]
# 4         [SA, ]
#          ...
# 61       [AUS, ]
# 62    [ICC/SA, ]
# 63       [AUS, ]
# 64       [AUS, ]
# 65       [ENG, ]
# Name: Player, Length: 66, dtype: object

# %%
data["Player"].str.split("(").str[1].str.split(")").str[0]
# Out:
# 0        AUS
# 1        ENG
# 2        AUS
# 3         SA
# 4         SA
#        ...
# 61       AUS
# 62    ICC/SA
# 63       AUS
# 64       AUS
# 65       ENG
# Name: Player, Length: 66, dtype: object

# %%
data["Country"]=data["Player"].str.split("(").str[1].str.split(")").str[0]

# %%
data.head()
# Out:
#              Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0  DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2    AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3   RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4   RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
#
#       SR  100  50  0   4s  6s Country
# 0  58.60   29  13  7  626   6     AUS
# 1  91.76    4   7  1  141  23     ENG
# 2  55.68    5   4  2  186   5     AUS
# 3  54.48    7  11  1  246  11      SA
# 4  54.48    7  11  1  246  11      SA

# %%
pd.set_option("display.max_rows",None)     #for all data...

# %%
data
# Out:
#                       Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0           DG Bradman (AUS)  1928-1948   52    80  10   6996   334  99.94
# 1             HC Brook (ENG)  2022-2023   12    20   1   1181   186  62.15
# 2             AC Voges (AUS)  2015-2016   20    31   7   1485  269*  61.87
# 3            RG Pollock (SA)  1963-1970   23    41   4   2256   274  60.97
# 4            RG Pollock (SA)  1963-1970   23    41   4   2256   274  60.97
# 5            GA Headley (WI)  1930-1954   22    40   4   2190  270*  60.83
# 6          H Sutcliffe (ENG)  1924-1935   54    84   9   4555   194  60.73
# 7            E Paynter (ENG)  1931-1939   20    31   5   1540   243  59.23
# 8        KF Barrington (ENG)  1955-1968   82   131  15   6806   256  58.67
# 9             ED Weekes (WI)  1948-1958   48    81   5   4455   207  58.61
# 10           SPD Smith (AUS)  2010-2023  102   181  22   9320   239  58.61
# ...

# %%
data["Country"]
# Out:
# 0         AUS
# 1         ENG
# 2         AUS
# 3          SA
# 4          SA
# 5          WI
# 6         ENG
# 7         ENG
# 8         ENG
# 9          WI
# 10        AUS
# 11        ENG
# 12         WI
# 13         SL
# 14         SL
# 15        ENG
# 16         WI
# 17        ENG
# 18         NZ
# 19     ICC/SA
# 20        ENG
# 21         NZ
# 22         NZ
# 23         WI
# 24        IND
# 25        AUS
# 26         SA
# 27        IND
# 28        AUS
# 29     ICC/WI
# 30        PAK
# 31    ICC/IND
# 32        PAK
# 33        PAK
# 34        AUS
# 35        AUS
# 36        ZIM
# 37        AUS
# 38         WI
# 39        IND
# 40        AUS
# 41        PAK
# 42        AUS
# 43         SA
# 44        AUS
# 45        ENG
# 46         WI
# 47        ENG
# 48         SL
# 49    ICC/PAK
# 50         WI
# 51        ENG
# 52    ICC/IND
# 53        IND
# 54        PAK
# 55        AUS
# 56         SA
# 57         SA
# 58        ENG
# 59         SL
# 60        AUS
# 61        AUS
# ...

# %%
data["Country"].replace("ICC/","",regex=True,inplace=True)    #without regex replace is not possible.

# %%
data
# Out:
#                       Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0           DG Bradman (AUS)  1928-1948   52    80  10   6996   334  99.94
# 1             HC Brook (ENG)  2022-2023   12    20   1   1181   186  62.15
# 2             AC Voges (AUS)  2015-2016   20    31   7   1485  269*  61.87
# 3            RG Pollock (SA)  1963-1970   23    41   4   2256   274  60.97
# 4            RG Pollock (SA)  1963-1970   23    41   4   2256   274  60.97
# 5            GA Headley (WI)  1930-1954   22    40   4   2190  270*  60.83
# 6          H Sutcliffe (ENG)  1924-1935   54    84   9   4555   194  60.73
# 7            E Paynter (ENG)  1931-1939   20    31   5   1540   243  59.23
# 8        KF Barrington (ENG)  1955-1968   82   131  15   6806   256  58.67
# 9             ED Weekes (WI)  1948-1958   48    81   5   4455   207  58.61
# 10           SPD Smith (AUS)  2010-2023  102   181  22   9320   239  58.61
# ...

# %%
data['Player']
# Out:
# 0             DG Bradman (AUS)
# 1               HC Brook (ENG)
# 2               AC Voges (AUS)
# 3              RG Pollock (SA)
# 4              RG Pollock (SA)
# 5              GA Headley (WI)
# 6            H Sutcliffe (ENG)
# 7              E Paynter (ENG)
# 8          KF Barrington (ENG)
# 9               ED Weekes (WI)
# 10             SPD Smith (AUS)
# 11            WR Hammond (ENG)
# 12              GS Sobers (WI)
# 13          KC Sangakkara (SL)
# 14          KC Sangakkara (SL)
# 15              JB Hobbs (ENG)
# 16             CL Walcott (WI)
# 17              L Hutton (ENG)
# 18            DJ Mitchell (NZ)
# 19          JH Kallis (ICC/SA)
# 20          GE Tyldesley (ENG)
# 21          KS Williamson (NZ)
# 22          KS Williamson (NZ)
# 23               CA Davis (WI)
# 24             VG Kambli (IND)
# 25           GS Chappell (AUS)
# 26              AD Nourse (SA)
# 27          SR Tendulkar (IND)
# 28         M Labuschagne (AUS)
# 29            BC Lara (ICC/WI)
# ...

# %%
data["Player"].str.split("(")
# Out:
# 0             [DG Bradman , AUS)]
# 1               [HC Brook , ENG)]
# 2               [AC Voges , AUS)]
# 3              [RG Pollock , SA)]
# 4              [RG Pollock , SA)]
# 5              [GA Headley , WI)]
# 6            [H Sutcliffe , ENG)]
# 7              [E Paynter , ENG)]
# 8          [KF Barrington , ENG)]
# 9               [ED Weekes , WI)]
# 10             [SPD Smith , AUS)]
# 11            [WR Hammond , ENG)]
# 12              [GS Sobers , WI)]
# 13          [KC Sangakkara , SL)]
# 14          [KC Sangakkara , SL)]
# 15              [JB Hobbs , ENG)]
# 16             [CL Walcott , WI)]
# 17              [L Hutton , ENG)]
# 18            [DJ Mitchell , NZ)]
# 19          [JH Kallis , ICC/SA)]
# 20          [GE Tyldesley , ENG)]
# 21          [KS Williamson , NZ)]
# 22          [KS Williamson , NZ)]
# 23               [CA Davis , WI)]
# 24             [VG Kambli , IND)]
# 25           [GS Chappell , AUS)]
# 26              [AD Nourse , SA)]
# ...

# %%
data["Player"].str.split("(").str[0]
# Out:
# 0            DG Bradman
# 1              HC Brook
# 2              AC Voges
# 3            RG Pollock
# 4            RG Pollock
# 5            GA Headley
# 6           H Sutcliffe
# 7             E Paynter
# 8         KF Barrington
# 9             ED Weekes
# 10            SPD Smith
# 11           WR Hammond
# 12            GS Sobers
# 13        KC Sangakkara
# 14        KC Sangakkara
# 15             JB Hobbs
# 16           CL Walcott
# 17             L Hutton
# 18          DJ Mitchell
# 19            JH Kallis
# 20         GE Tyldesley
# 21        KS Williamson
# 22        KS Williamson
# 23             CA Davis
# 24            VG Kambli
# 25          GS Chappell
# 26            AD Nourse
# 27         SR Tendulkar
# 28        M Labuschagne
# 29              BC Lara
# 30        Javed Miandad
# 31             R Dravid
# 32      Mohammad Yousuf
# 33          Younis Khan
# 34           RT Ponting
# 35              J Ryder
# 36             A Flower
# 37           MEK Hussey
# ...

# %%
data["Player"].str.split("(").str[0].str.strip()
# Out:
# 0            DG Bradman
# 1              HC Brook
# 2              AC Voges
# 3            RG Pollock
# 4            RG Pollock
# 5            GA Headley
# 6           H Sutcliffe
# 7             E Paynter
# 8         KF Barrington
# 9             ED Weekes
# 10            SPD Smith
# 11           WR Hammond
# 12            GS Sobers
# 13        KC Sangakkara
# 14        KC Sangakkara
# 15             JB Hobbs
# 16           CL Walcott
# 17             L Hutton
# 18          DJ Mitchell
# 19            JH Kallis
# 20         GE Tyldesley
# 21        KS Williamson
# 22        KS Williamson
# 23             CA Davis
# 24            VG Kambli
# 25          GS Chappell
# 26            AD Nourse
# 27         SR Tendulkar
# 28        M Labuschagne
# 29              BC Lara
# 30        Javed Miandad
# 31             R Dravid
# 32      Mohammad Yousuf
# 33          Younis Khan
# 34           RT Ponting
# 35              J Ryder
# 36             A Flower
# 37           MEK Hussey
# ...

# %%
data["Player"]=data["Player"].str.split("(").str[0].str.strip()

# %%
data[:]     #after pd.set option query.....this query shows all columns and rows..
# Out:
#                Player       Span  Mat  Inns  NO   Runs    HS    Ave      BF  \
# 0          DG Bradman  1928-1948   52    80  10   6996   334  99.94   9800+
# 1            HC Brook  2022-2023   12    20   1   1181   186  62.15    1287
# 2            AC Voges  2015-2016   20    31   7   1485  269*  61.87    2667
# 3          RG Pollock  1963-1970   23    41   4   2256   274  60.97   1707+
# 4          RG Pollock  1963-1970   23    41   4   2256   274  60.97   1707+
# 5          GA Headley  1930-1954   22    40   4   2190  270*  60.83    416+
# 6         H Sutcliffe  1924-1935   54    84   9   4555   194  60.73   6558+
# 7           E Paynter  1931-1939   20    31   5   1540   243  59.23   1288+
# 8       KF Barrington  1955-1968   82   131  15   6806   256  58.67   4957+
# 9           ED Weekes  1948-1958   48    81   5   4455   207  58.61       -
# 10          SPD Smith  2010-2023  102   181  22   9320   239  58.61   17292
# ...

# %%
data["Span"]
# Out:
# 0     1928-1948
# 1     2022-2023
# 2     2015-2016
# 3     1963-1970
# 4     1963-1970
# 5     1930-1954
# 6     1924-1935
# 7     1931-1939
# 8     1955-1968
# 9     1948-1958
# 10    2010-2023
# 11    1927-1947
# 12    1954-1974
# 13    2000-2015
# 14    2000-2015
# 15    1908-1930
# 16    1948-1960
# 17    1937-1955
# 18    2019-2023
# 19    1995-2013
# 20    1921-1929
# 21    2010-2023
# 22    2010-2023
# 23    1968-1973
# 24    1993-1995
# 25    1970-1984
# 26    1935-1951
# 27    1989-2013
# 28    2018-2023
# 29    1990-2006
# 30    1976-1993
# 31    1996-2012
# 32    1998-2010
# 33    2000-2017
# 34    1995-2012
# 35    1920-1929
# 36    1992-2002
# 37    2005-2013
# 38    1994-2015
# 39    1971-1987
# 40    1985-2004
# 41    2021-2023
# 42    1994-2009
# 43    2004-2018
# 44    1978-1994
# 45    2012-2023
# 46    1974-1991
# 47    1937-1957
# 48    1997-2014
# 49    1992-2007
# 50    1948-1963
# 51    1911-1928
# 52    2001-2013
# 53    2011-2023
# 54    2019-2021
# ...

# %%
data["Span"].str.split("-")
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1963, 1970]
# 5     [1930, 1954]
# 6     [1924, 1935]
# 7     [1931, 1939]
# 8     [1955, 1968]
# 9     [1948, 1958]
# 10    [2010, 2023]
# 11    [1927, 1947]
# 12    [1954, 1974]
# 13    [2000, 2015]
# 14    [2000, 2015]
# 15    [1908, 1930]
# 16    [1948, 1960]
# 17    [1937, 1955]
# 18    [2019, 2023]
# 19    [1995, 2013]
# 20    [1921, 1929]
# 21    [2010, 2023]
# 22    [2010, 2023]
# 23    [1968, 1973]
# 24    [1993, 1995]
# 25    [1970, 1984]
# 26    [1935, 1951]
# 27    [1989, 2013]
# 28    [2018, 2023]
# 29    [1990, 2006]
# 30    [1976, 1993]
# 31    [1996, 2012]
# 32    [1998, 2010]
# 33    [2000, 2017]
# 34    [1995, 2012]
# 35    [1920, 1929]
# 36    [1992, 2002]
# 37    [2005, 2013]
# 38    [1994, 2015]
# 39    [1971, 1987]
# 40    [1985, 2004]
# 41    [2021, 2023]
# 42    [1994, 2009]
# 43    [2004, 2018]
# 44    [1978, 1994]
# 45    [2012, 2023]
# 46    [1974, 1991]
# ...

# %%
data["Span"].str.split("-").str[0]
# Out:
# 0     1928
# 1     2022
# 2     2015
# 3     1963
# 4     1963
# 5     1930
# 6     1924
# 7     1931
# 8     1955
# 9     1948
# 10    2010
# 11    1927
# 12    1954
# 13    2000
# 14    2000
# 15    1908
# 16    1948
# 17    1937
# 18    2019
# 19    1995
# 20    1921
# 21    2010
# 22    2010
# 23    1968
# 24    1993
# 25    1970
# 26    1935
# 27    1989
# 28    2018
# 29    1990
# 30    1976
# 31    1996
# 32    1998
# 33    2000
# 34    1995
# 35    1920
# 36    1992
# 37    2005
# 38    1994
# 39    1971
# 40    1985
# 41    2021
# 42    1994
# 43    2004
# 44    1978
# 45    2012
# 46    1974
# 47    1937
# 48    1997
# 49    1992
# 50    1948
# 51    1911
# 52    2001
# 53    2011
# 54    2019
# 55    2004
# 56    1961
# 57    1929
# 58    1893
# 59    2001
# 60    1948
# 61    1965
# 62    2002
# 63    1924
# 64    1930
# 65    1928
# Name: Span, dtype: object

# %%
data["Span"].str.split("-").str[1]
# Out:
# 0     1948
# 1     2023
# 2     2016
# 3     1970
# 4     1970
# 5     1954
# 6     1935
# 7     1939
# 8     1968
# 9     1958
# 10    2023
# 11    1947
# 12    1974
# 13    2015
# 14    2015
# 15    1930
# 16    1960
# 17    1955
# 18    2023
# 19    2013
# 20    1929
# 21    2023
# 22    2023
# 23    1973
# 24    1995
# 25    1984
# 26    1951
# 27    2013
# 28    2023
# 29    2006
# 30    1993
# 31    2012
# 32    2010
# 33    2017
# 34    2012
# 35    1929
# 36    2002
# 37    2013
# 38    2015
# 39    1987
# 40    2004
# 41    2023
# 42    2009
# 43    2018
# 44    1994
# 45    2023
# 46    1991
# 47    1957
# 48    2014
# 49    2007
# 50    1963
# 51    1928
# 52    2013
# 53    2023
# 54    2021
# 55    2015
# 56    1966
# 57    1949
# 58    1905
# 59    2013
# 60    1963
# 61    1981
# 62    2014
# 63    1934
# 64    1938
# 65    1934
# Name: Span, dtype: object

# %%
data["Debut Year"]=data["Span"].str.split("-").str[0]

# %%
data["Ending Year*"]=data["Span"].str.split("-").str[1]

# %%
data.head()
# Out:
#        Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF     SR  100  \
# 0  DG Bradman  1928-1948   52    80  10  6996   334  99.94  9800+  58.60   29
# 1    HC Brook  2022-2023   12    20   1  1181   186  62.15   1287  91.76    4
# 2    AC Voges  2015-2016   20    31   7  1485  269*  61.87   2667  55.68    5
# 3  RG Pollock  1963-1970   23    41   4  2256   274  60.97  1707+  54.48    7
# 4  RG Pollock  1963-1970   23    41   4  2256   274  60.97  1707+  54.48    7
#
#    50  0   4s  6s Country Debut Year Ending Year*
# 0  13  7  626   6     AUS       1928         1948
# 1   7  1  141  23     ENG       2022         2023
# 2   4  2  186   5     AUS       2015         2016
# 3  11  1  246  11      SA       1963         1970
# 4  11  1  246  11      SA       1963         1970

# %%
data.drop("Span",axis=1,inplace=True)

# %%
data.head(1)
# Out:
#        Player  Mat  Inns  NO  Runs   HS    Ave     BF     SR  100  50  0   4s  \
# 0  DG Bradman   52    80  10  6996  334  99.94  9800+  58.60   29  13  7  626
#
#    6s Country Debut Year Ending Year*
# 0   6     AUS       1928         1948

# %%
data.dtypes
# Out:
# Player           object
# Mat               int64
# Inns              int64
# NO                int64
# Runs              int64
# HS               object
# Ave             float64
# BF               object
# SR               object
# 100               int64
# 50                int64
# 0                 int64
# 4s                int64
# 6s                int64
# Country          object
# Debut Year       object
# Ending Year*     object
# dtype: object

# %%
#Here debut and ending year data rtpes is object(string) and i want to minus(-) the ending and debut year
#so first change data type object to int and then perform query...

# %%
data["Debut Year"]=data["Debut Year"].astype("int")

# %%
data["Ending Year*"]=data["Ending Year*"].astype("int")

# %%
data.dtypes
# Out:
# Player           object
# Mat               int64
# Inns              int64
# NO                int64
# Runs              int64
# HS               object
# Ave             float64
# BF               object
# SR               object
# 100               int64
# 50                int64
# 0                 int64
# 4s                int64
# 6s                int64
# Country          object
# Debut Year        int32
# Ending Year*      int32
# dtype: object

# %%
data["Career_Length"]=data["Ending Year*"]-data["Debut Year"]

# %%
data.head()
# Out:
#        Player  Mat  Inns  NO  Runs    HS    Ave     BF     SR  100  50  0  \
# 0  DG Bradman   52    80  10  6996   334  99.94  9800+  58.60   29  13  7
# 1    HC Brook   12    20   1  1181   186  62.15   1287  91.76    4   7  1
# 2    AC Voges   20    31   7  1485  269*  61.87   2667  55.68    5   4  2
# 3  RG Pollock   23    41   4  2256   274  60.97  1707+  54.48    7  11  1
# 4  RG Pollock   23    41   4  2256   274  60.97  1707+  54.48    7  11  1
#
#     4s  6s Country  Debut Year  Ending Year*  Career_Length
# 0  626   6     AUS        1928          1948             20
# 1  141  23     ENG        2022          2023              1
# 2  186   5     AUS        2015          2016              1
# 3  246  11      SA        1963          1970              7
# 4  246  11      SA        1963          1970              7

# %%
data.columns
# Out:
# Index(['Player', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR', '100',
#        '50', '0', '4s', '6s', 'Country', 'Debut Year', 'Ending Year*',
#        'Career_Length'],
#       dtype='object')

# %%
data=data[['Player','Country' ,'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR', '100',
       '50', '0', '4s', '6s', 'Debut Year', 'Ending Year*',
       'Career_Length']]

#this query for change the order of rows....

# %%
data.head(1)
# Out:
#        Player Country  Mat  Inns  NO  Runs   HS    Ave     BF     SR  100  50  \
# 0  DG Bradman     AUS   52    80  10  6996  334  99.94  9800+  58.60   29  13
#
#    0   4s  6s  Debut Year  Ending Year*  Career_Length
# 0  7  626   6        1928          1948             20

# %%
data.columns
# Out:
# Index(['Player', 'Country', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF',
#        'SR', '100', '50', '0', '4s', '6s', 'Debut Year', 'Ending Year*',
#        'Career_Length'],
#       dtype='object')

# %%
a={"Mat":"Matches","Inns":"Innings","NO":"Not Out","HS":"High Score" } 

#first method of change columns name using dictinory....

# %%
data.rename(columns=a,inplace=True)

# %%
data.head(1)
# Out:
#        Player Country  Matches  Innings  Not Out  Runs High Score    Ave  \
# 0  DG Bradman     AUS       52       80       10  6996        334  99.94
#
#       BF     SR  100  50  0   4s  6s  Debut Year  Ending Year*  Career_Length
# 0  9800+  58.60   29  13  7  626   6        1928          1948             20

# %%
data.columns
# Out:
# Index(['Player', 'Country', 'Matches', 'Innings', 'Not Out', 'Runs',
#        'High Score', 'Ave', 'BF', 'SR', '100', '50', '0', '4s', '6s',
#        'Debut Year', 'Ending Year*', 'Career_Length'],
#       dtype='object')

# %%
data.columns=['Player', 'Country', 'Matches', 'Innings', 'Not Out', 'Runs',
       'High Score', 'Average', 'Ball Faced', 'Strike Rate', '100', '50', '0', '4s', '6s',
       'Debut Year', 'Ending Year*', 'Career_Length']

#second method of change columns names using list method and this method is very esay....
#first method is just for information and interview question....
#use always second method for change columns names..

# %%
data.head(1)
# Out:
#        Player Country  Matches  Innings  Not Out  Runs High Score  Average  \
# 0  DG Bradman     AUS       52       80       10  6996        334    99.94
#
#   Ball Faced Strike Rate  100  50  0   4s  6s  Debut Year  Ending Year*  \
# 0      9800+       58.60   29  13  7  626   6        1928          1948
#
#    Career_Length
# 0             20

# %%
data[data["Ball Faced"]=="-"]
# Out:
#             Player Country  Matches  Innings  Not Out  Runs High Score  \
# 9        ED Weekes      WI       48       81        5  4455        207
# 16      CL Walcott      WI       44       74        7  3798        220
# 58  Hon.FS Jackson     ENG       20       33        4  1415       144*
#
#     Average Ball Faced Strike Rate  100  50  0   4s  6s  Debut Year  \
# 9     58.61          -           -   15  19  6  258   2        1948
# 16    56.68          -           -   15  14  1  107  11        1948
# 58    48.79          -           -    5   6  3   51   0        1893
#
#     Ending Year*  Career_Length
# 9           1958             10
# 16          1960             12
# 58          1905             12

# %%
data.dtypes
# Out:
# Player            object
# Country           object
# Matches            int64
# Innings            int64
# Not Out            int64
# Runs               int64
# High Score        object
# Average          float64
# Ball Faced        object
# Strike Rate       object
# 100                int64
# 50                 int64
# 0                  int64
# 4s                 int64
# 6s                 int64
# Debut Year         int32
# Ending Year*       int32
# Career_Length      int32
# dtype: object

# %%
data[(data["Matches"]>=50) & (data["Matches"]<=60)]
# Out:
#          Player Country  Matches  Innings  Not Out  Runs High Score  Average  \
# 0    DG Bradman     AUS       52       80       10  6996        334    99.94
# 6   H Sutcliffe     ENG       54       84        9  4555        194    60.73
# 50  FMM Worrell      WI       51       87        9  3860        261    49.48
#
#    Ball Faced Strike Rate  100  50   0   4s  6s  Debut Year  Ending Year*  \
# 0       9800+       58.60   29  13   7  626   6        1928          1948
# 6       6558+       34.59   16  23   2  202   6        1924          1935
# 50       488+       40.16    9  22  11  240  11        1948          1963
#
#     Career_Length
# 0              20
# 6              11
# 50             15

# %%
data[(data["Matches"]>=50) & (data["Matches"]<=60)]["Strike Rate"]
# Out:
# 0     58.60
# 6     34.59
# 50    40.16
# Name: Strike Rate, dtype: object

# %%
data["Strike Rate"]=data["Strike Rate"].replace("-","0.0")

# %%
data["Strike Rate"]=data["Strike Rate"].astype("float")

# %%
data.dtypes
# Out:
# Player            object
# Country           object
# Matches            int64
# Innings            int64
# Not Out            int64
# Runs               int64
# High Score        object
# Average          float64
# Ball Faced        object
# Strike Rate      float64
# 100                int64
# 50                 int64
# 0                  int64
# 4s                 int64
# 6s                 int64
# Debut Year         int32
# Ending Year*       int32
# Career_Length      int32
# dtype: object

# %%
data[(data["Matches"]>=50) & (data["Matches"]<=60)]["Strike Rate"].mean()  #strike rate mean.
# Out:
# 44.449999999999996

# %%
x=data[(data["Matches"]>=50) & (data["Matches"]<=60)]["Strike Rate"].mean()  #strike rate mean.

# %%
data["Strike Rate"]=data["Strike Rate"].replace(0.0,x)

# %%
data["Strike Rate"]
# Out:
# 0     58.60
# 1     91.76
# 2     55.68
# 3     54.48
# 4     54.48
# 5     56.00
# 6     34.59
# 7     45.88
# 8     42.42
# 9     44.45
# 10    53.89
# 11    38.07
# 12    53.58
# 13    54.19
# 14    54.19
# 15    46.22
# 16    44.45
# 17    39.34
# 18    55.07
# 19    45.97
# 20    29.21
# 21    51.44
# 22    51.44
# 23    35.48
# 24    59.46
# 25    51.53
# 26    63.88
# 27    54.04
# 28    53.02
# 29    60.51
# 30    45.99
# 31    42.51
# 32    52.39
# 33    52.12
# 34    58.72
# 35    44.86
# 36    45.07
# 37    50.13
# 38    43.31
# 39    43.35
# 40    48.64
# 41    44.13
# 42    60.10
# 43    54.51
# 44    41.09
# 45    56.75
# 46    69.77
# 47    38.81
# 48    51.45
# 49    54.02
# 50    40.16
# 51    30.04
# 52    82.23
# 53    55.23
# 54    48.26
# 55    55.92
# 56    37.74
# 57    29.11
# 58    44.45
# 59    46.92
# 60    43.74
# 61    49.16
# 62    59.67
# 63    44.77
# 64    60.02
# 65    25.59
# Name: Strike Rate, dtype: float64

# %%
data["Ball Faced"]
# Out:
# 0      9800+
# 1       1287
# 2       2667
# 3      1707+
# 4      1707+
# 5       416+
# 6      6558+
# 7      1288+
# 8      4957+
# 9          -
# 10     17292
# 11     7491+
# 12     4063+
# 13     22882
# 14     22882
# 15     5363+
# 16         -
# 17     2844+
# 18      2569
# 19     28903
# 20      178+
# 21     16014
# 22     16014
# 23      665+
# 24      1823
# 25    13079+
# 26      108+
# 27    29437+
# 28      7146
# 29     19753
# 30    15164+
# 31     31258
# 32     14372
# 33     19375
# 34     22782
# 35     2035+
# 36     10636
# 37     12436
# 38     27395
# 39    14184+
# 40     22461
# 41      2764
# 42     14349
# 43     16077
# 44    27002+
# 45     20113
# 46     9613+
# 47     2731+
# 48     22959
# 49     16345
# 50      488+
# 51      619+
# 52     10441
# 53     15708
# 54      2445
# 55     15456
# 56      885+
# 57      158+
# 58         -
# 59     11641
# 60     1799+
# 61     8662+
# 62     15525
# 63     3118+
# 64     3217+
# 65     2110+
# ...

# %%
data.dtypes
# Out:
# Player            object
# Country           object
# Matches            int64
# Innings            int64
# Not Out            int64
# Runs               int64
# High Score        object
# Average          float64
# Ball Faced        object
# Strike Rate      float64
# 100                int64
# 50                 int64
# 0                  int64
# 4s                 int64
# 6s                 int64
# Debut Year         int32
# Ending Year*       int32
# Career_Length      int32
# dtype: object

# %%
data[data["Ball Faced"]=="-"]
# Out:
#             Player Country  Matches  Innings  Not Out  Runs High Score  \
# 9        ED Weekes      WI       48       81        5  4455        207
# 16      CL Walcott      WI       44       74        7  3798        220
# 58  Hon.FS Jackson     ENG       20       33        4  1415       144*
#
#     Average Ball Faced  Strike Rate  100  50  0   4s  6s  Debut Year  \
# 9     58.61          -        44.45   15  19  6  258   2        1948
# 16    56.68          -        44.45   15  14  1  107  11        1948
# 58    48.79          -        44.45    5   6  3   51   0        1893
#
#     Ending Year*  Career_Length
# 9           1958             10
# 16          1960             12
# 58          1905             12

# %%
data["Ball Faced"].dtype    #in output (O) is object..
# Out:
# dtype('O')

# %%
data["Ball Faced"]=data["Ball Faced"].replace("-","0")

# %%
data["Ball Faced"]=data["Ball Faced"].replace("0.0","0")

# %%
data["Ball Faced"]
# Out:
# 0      9800
# 1      1287
# 2      2667
# 3      1707
# 4      1707
# 5       416
# 6      6558
# 7      1288
# 8      4957
# 9         0
# 10    17292
# 11     7491
# 12     4063
# 13    22882
# 14    22882
# 15     5363
# 16        0
# 17     2844
# 18     2569
# 19    28903
# 20      178
# 21    16014
# 22    16014
# 23      665
# 24     1823
# 25    13079
# 26      108
# 27    29437
# 28     7146
# 29    19753
# 30    15164
# 31    31258
# 32    14372
# 33    19375
# 34    22782
# 35     2035
# 36    10636
# 37    12436
# 38    27395
# 39    14184
# 40    22461
# 41     2764
# 42    14349
# 43    16077
# 44    27002
# 45    20113
# 46     9613
# 47     2731
# 48    22959
# 49    16345
# 50      488
# 51      619
# 52    10441
# 53    15708
# 54     2445
# 55    15456
# 56      885
# 57      158
# 58        0
# 59    11641
# 60     1799
# 61     8662
# 62    15525
# 63     3118
# 64     3217
# 65     2110
# Name: Ball Faced, dtype: object

# %%
data[data["Ball Faced"]=="0"]
# Out:
#             Player Country  Matches  Innings  Not Out  Runs High Score  \
# 9        ED Weekes      WI       48       81        5  4455        207
# 16      CL Walcott      WI       44       74        7  3798        220
# 58  Hon.FS Jackson     ENG       20       33        4  1415       144*
#
#     Average Ball Faced  Strike Rate  100  50  0   4s  6s  Debut Year  \
# 9     58.61          0        44.45   15  19  6  258   2        1948
# 16    56.68          0        44.45   15  14  1  107  11        1948
# 58    48.79          0        44.45    5   6  3   51   0        1893
#
#     Ending Year*  Career_Length
# 9           1958             10
# 16          1960             12
# 58          1905             12

# %%
data["Ball Faced"]=data["Ball Faced"].replace("[+]","",regex=True)

# %%
data["Ball Faced"]
# Out:
# 0      9800
# 1      1287
# 2      2667
# 3      1707
# 4      1707
# 5       416
# 6      6558
# 7      1288
# 8      4957
# 9         0
# 10    17292
# 11     7491
# 12     4063
# 13    22882
# 14    22882
# 15     5363
# 16        0
# 17     2844
# 18     2569
# 19    28903
# 20      178
# 21    16014
# 22    16014
# 23      665
# 24     1823
# 25    13079
# 26      108
# 27    29437
# 28     7146
# 29    19753
# 30    15164
# 31    31258
# 32    14372
# 33    19375
# 34    22782
# 35     2035
# 36    10636
# 37    12436
# 38    27395
# 39    14184
# 40    22461
# 41     2764
# 42    14349
# 43    16077
# 44    27002
# 45    20113
# 46     9613
# 47     2731
# 48    22959
# 49    16345
# 50      488
# 51      619
# 52    10441
# 53    15708
# 54     2445
# 55    15456
# 56      885
# 57      158
# 58        0
# 59    11641
# 60     1799
# 61     8662
# 62    15525
# 63     3118
# 64     3217
# 65     2110
# Name: Ball Faced, dtype: object

# %%
data.dtypes
# Out:
# Player            object
# Country           object
# Matches            int64
# Innings            int64
# Not Out            int64
# Runs               int64
# High Score        object
# Average          float64
# Ball Faced        object
# Strike Rate      float64
# 100                int64
# 50                 int64
# 0                  int64
# 4s                 int64
# 6s                 int64
# Debut Year         int32
# Ending Year*       int32
# Career_Length      int32
# dtype: object

# %%
data["Ball Faced"]=data["Ball Faced"].astype("int")

# %%
data["Ball Faced"].dtype
# Out:
# dtype('int32')

# %%
data[data["Ball Faced"]==0]
# Out:
#             Player Country  Matches  Innings  Not Out  Runs High Score  \
# 9        ED Weekes      WI       48       81        5  4455        207
# 16      CL Walcott      WI       44       74        7  3798        220
# 58  Hon.FS Jackson     ENG       20       33        4  1415       144*
#
#     Average  Ball Faced  Strike Rate  100  50  0   4s  6s  Debut Year  \
# 9     58.61           0        44.45   15  19  6  258   2        1948
# 16    56.68           0        44.45   15  14  1  107  11        1948
# 58    48.79           0        44.45    5   6  3   51   0        1893
#
#     Ending Year*  Career_Length
# 9           1958             10
# 16          1960             12
# 58          1905             12

# %%
data[data["Player"]=="ED Weekes"]
# Out:
#       Player Country  Matches  Innings  Not Out  Runs High Score  Average  \
# 9  ED Weekes      WI       48       81        5  4455        207    58.61
#
#    Ball Faced  Strike Rate  100  50  0   4s  6s  Debut Year  Ending Year*  \
# 9           0        44.45   15  19  6  258   2        1948          1958
#
#    Career_Length
# 9             10

# %%
data[data["Player"]=="ED Weekes"][["Runs","Strike Rate"]]
# Out:
#    Runs  Strike Rate
# 9  4455        44.45

# %%
data[data["Player"]=="ED Weekes"]["Runs"]*2
# Out:
# 9    8910
# Name: Runs, dtype: int64

# %%
data["Ball Faced"].replace(0,8910,inplace=True)

# %%
data
# Out:
#                Player Country  Matches  Innings  Not Out   Runs High Score  \
# 0          DG Bradman     AUS       52       80       10   6996        334
# 1            HC Brook     ENG       12       20        1   1181        186
# 2            AC Voges     AUS       20       31        7   1485       269*
# 3          RG Pollock      SA       23       41        4   2256        274
# 4          RG Pollock      SA       23       41        4   2256        274
# 5          GA Headley      WI       22       40        4   2190       270*
# 6         H Sutcliffe     ENG       54       84        9   4555        194
# 7           E Paynter     ENG       20       31        5   1540        243
# 8       KF Barrington     ENG       82      131       15   6806        256
# 9           ED Weekes      WI       48       81        5   4455        207
# 10          SPD Smith     AUS      102      181       22   9320        239
# ...

# %%
data["High Score"]=data["High Score"].replace("[*]","",regex=True)

# %%
data
# Out:
#                Player Country  Matches  Innings  Not Out   Runs High Score  \
# 0          DG Bradman     AUS       52       80       10   6996        334
# 1            HC Brook     ENG       12       20        1   1181        186
# 2            AC Voges     AUS       20       31        7   1485        269
# 3          RG Pollock      SA       23       41        4   2256        274
# 4          RG Pollock      SA       23       41        4   2256        274
# 5          GA Headley      WI       22       40        4   2190        270
# 6         H Sutcliffe     ENG       54       84        9   4555        194
# 7           E Paynter     ENG       20       31        5   1540        243
# 8       KF Barrington     ENG       82      131       15   6806        256
# 9           ED Weekes      WI       48       81        5   4455        207
# 10          SPD Smith     AUS      102      181       22   9320        239
# ...

# %%
data.dtypes
# Out:
# Player            object
# Country           object
# Matches            int64
# Innings            int64
# Not Out            int64
# Runs               int64
# High Score        object
# Average          float64
# Ball Faced         int32
# Strike Rate      float64
# 100                int64
# 50                 int64
# 0                  int64
# 4s                 int64
# 6s                 int64
# Debut Year         int32
# Ending Year*       int32
# Career_Length      int32
# dtype: object

# %%
data["High Score"]=data["High Score"].astype("int")

# %%
data.dtypes
# Out:
# Player            object
# Country           object
# Matches            int64
# Innings            int64
# Not Out            int64
# Runs               int64
# High Score         int32
# Average          float64
# Ball Faced         int32
# Strike Rate      float64
# 100                int64
# 50                 int64
# 0                  int64
# 4s                 int64
# 6s                 int64
# Debut Year         int32
# Ending Year*       int32
# Career_Length      int32
# dtype: object
