# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel("D:\\LIVE PROJECT PYTHON\\Data (1).xlsx")

# %%
data.head()
# Out:
#              Player       Span Mat  Inns  NO  Runs    HS    Ave     BF     SR  \
# 0  DG Bradman (AUS)  1928-1948  52    80  10  6996   334  99.94  9800+  58.60
# 1    HC Brook (ENG)  2022-2023  12    20   1  1181   186  62.15   1287  91.76
# 2    AC Voges (AUS)  2015-2016  20    31   7  1485  269*  61.87   2667  55.68
# 3   RG Pollock (SA)  1963-1970  23    41   4  2256   274  60.97  1707+  54.48
# 4   RG Pollock (SA)  1963-1970  23    41   4  2256   274  60.97  1707+  54.48
#
#    100  50  0   4s  6s
# 0   29  13  7  626   6
# 1    4   7  1  141  23
# 2    5   4  2  186   5
# 3    7  11  1  246  11
# 4    7  11  1  246  11

# %%
#just example

# %%
a=5+6j

# %%
a.imag
# Out:
# 6.0

# %%
a.real
# Out:
# 5.0

# %%
a.conjugate()        #opposite a number.
# Out:
# (5-6j)

# %%
a
# Out:
# (5+6j)

# %%
a="we are learningg python"

# %%
a[0:5]
# Out:
# 'we ar'

# %%
a[::-1]     #reverse order
# Out:
# 'nohtyp ggninrael era ew'

# %%
a="mayur"

# %%
a.upper()
# Out:
# 'MAYUR'

# %%
a
# Out:
# 'mayur'

# %%
a.capitalize()
# Out:
# 'Mayur'

# %%
a
# Out:
# 'mayur'

# %%
a.title()
# Out:
# 'Mayur'

# %%
b="we are learning python"

# %%
b.title()          #TITLE are use for all words first letter capital.
# Out:
# 'We Are Learning Python'

# %%
a="    mayur"

# %%
len(a)
# Out:
# 9

# %%
a.strip()
# Out:
# 'mayur'

# %%
c="Mayur-Data Scientist-Fingertips"

# %%
c.split()
# Out:
# ['Mayur-Data', 'Scientist-Fingertips']

# %%
d="Mayur Data Scientist Fingertips"

# %%
d.split()
# Out:
# ['Mayur', 'Data', 'Scientist', 'Fingertips']

# %%
d.split()[1]
# Out:
# 'Data'

# %%
df=pd.read_excel("C:\\Users\\mayur\\OneDrive\\Desktop\\New Microsoft Excel Worksheet.xlsx")

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 61   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 62  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 63  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 64    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 65   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7   626   6
# ...

# %%
df.head()
# Out:
#              Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0  DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2    AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3   RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4   RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
#
#       SR  100  50  0   4s  6s
# 0  58.60   29  13  7  626   6
# 1  91.76    4   7  1  141  23
# 2  55.68    5   4  2  186   5
# 3  54.48    7  11  1  246  11
# 4  54.48    7  11  1  246  11

# %%
df.columns
# Out:
# Index(['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR',
#        '100', '50', '0', '4s', '6s'],
#       dtype='object')

# %%
df.columns=['Player', 'Span', 'Matches', 'Innings', 'Not Out', 'Runs', 'High Score', 'Average', 'Ball Faced', 'Strike Rate',
       '100', '50', '0', '4s', '6s']

# %%
df.head()
# Out:
#              Player       Span  Matches  Innings  Not Out  Runs High Score  \
# 0  DG Bradman (AUS)  1928-1948       52       80       10  6996        334
# 1    HC Brook (ENG)  2022-2023       12       20        1  1181        186
# 2    AC Voges (AUS)  2015-2016       20       31        7  1485       269*
# 3   RG Pollock (SA)  1963-1970       23       41        4  2256        274
# 4   RG Pollock (SA)  1963-1970       23       41        4  2256        274
#
#    Average Ball Faced Strike Rate  100  50  0   4s  6s
# 0    99.94      9800+       58.60   29  13  7  626   6
# 1    62.15       1287       91.76    4   7  1  141  23
# 2    61.87       2667       55.68    5   4  2  186   5
# 3    60.97      1707+       54.48    7  11  1  246  11
# 4    60.97      1707+       54.48    7  11  1  246  11

# %%
#again over write a file and see a second method of change column name...

# %%
data=pd.read_excel("D:\\LIVE PROJECT PYTHON\\Data (1).xlsx")

# %%
df.columns
# Out:
# Index(['Player', 'Span', 'Matches', 'Innings', 'Not Out', 'Runs', 'High Score',
#        'Average', 'Ball Faced', 'Strike Rate', '100', '50', '0', '4s', '6s'],
#       dtype='object')

# %%
a={'Mat':'Matches', 'Inns':'Innings', 'NO':'Not Out', 'HS':'High Score', 'Ave':'Average', 'BF':'Ball Faced','SR':'Strike Rate'}

# %%
df.rename(columns=a)
# Out:
#                Player       Span  Matches  Innings  Not Out  Runs High Score  \
# 0    DG Bradman (AUS)  1928-1948       52       80       10  6996        334
# 1      HC Brook (ENG)  2022-2023       12       20        1  1181        186
# 2      AC Voges (AUS)  2015-2016       20       31        7  1485       269*
# 3     RG Pollock (SA)  1963-1970       23       41        4  2256        274
# 4     RG Pollock (SA)  1963-1970       23       41        4  2256        274
# ..                ...        ...      ...      ...      ...   ...        ...
# 61   KD Walters (AUS)  1965-1981       74      125       14  5357        250
# 62  GC Smith (ICC/SA)  2002-2014      117      205       13  9265        277
# 63  WH Ponsford (AUS)  1924-1934       29       48        4  2122        266
# 64    SJ McCabe (AUS)  1930-1938       39       62        5  2748        232
# 65   DR Jardine (ENG)  1928-1934       22       33        6  1296        127
#
# ...

# %%
df.head(2)
# Out:
#              Player       Span  Matches  Innings  Not Out  Runs High Score  \
# 0  DG Bradman (AUS)  1928-1948       52       80       10  6996        334
# 1    HC Brook (ENG)  2022-2023       12       20        1  1181        186
#
#    Average Ball Faced Strike Rate  100  50  0   4s  6s
# 0    99.94      9800+       58.60   29  13  7  626   6
# 1    62.15       1287       91.76    4   7  1  141  23

# %%
df.isnull().count()
# Out:
# Player         66
# Span           66
# Matches        66
# Innings        66
# Not Out        66
# Runs           66
# High Score     66
# Average        66
# Ball Faced     66
# Strike Rate    66
# 100            66
# 50             66
# 0              66
# 4s             66
# 6s             66
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Player         0
# Span           0
# Matches        0
# Innings        0
# Not Out        0
# Runs           0
# High Score     0
# Average        0
# Ball Faced     0
# Strike Rate    0
# 100            0
# 50             0
# 0              0
# 4s             0
# 6s             0
# dtype: int64

# %%
df.duplicated()       #where duplicate values is written as (True).
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
#       ...
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# Length: 66, dtype: bool

# %%
df["Player"]
# Out:
# 0      DG Bradman (AUS)
# 1        HC Brook (ENG)
# 2        AC Voges (AUS)
# 3       RG Pollock (SA)
# 4       RG Pollock (SA)
#             ...
# 61     KD Walters (AUS)
# 62    GC Smith (ICC/SA)
# 63    WH Ponsford (AUS)
# 64      SJ McCabe (AUS)
# 65     DR Jardine (ENG)
# Name: Player, Length: 66, dtype: object

# %%
df[df["Player"].duplicated()==True]      #for find duplicate value.
# Out:
#                 Player       Span  Matches  Innings  Not Out   Runs  \
# 4      RG Pollock (SA)  1963-1970       23       41        4   2256
# 14  KC Sangakkara (SL)  2000-2015      134      233       17  12400
# 22  KS Williamson (NZ)  2010-2023       95      166       16   8239
#
#    High Score  Average Ball Faced Strike Rate  100  50   0    4s  6s
# 4         274    60.97      1707+       54.48    7  11   1   246  11
# 14        319    57.40      22882       54.19   38  52  11  1491  51
# 22        251    54.92      16014       51.44   29  33  10   910  21

# %%
df[df["Player"]=="RG Pollock (SA)"]     #for how many times player names appear.
# Out:
#             Player       Span  Matches  Innings  Not Out  Runs High Score  \
# 3  RG Pollock (SA)  1963-1970       23       41        4  2256        274
# 4  RG Pollock (SA)  1963-1970       23       41        4  2256        274
#
#    Average Ball Faced Strike Rate  100  50  0   4s  6s
# 3    60.97      1707+       54.48    7  11  1  246  11
# 4    60.97      1707+       54.48    7  11  1  246  11

# %%
df[df["Player"]=="VG Kambli (IND)"]
# Out:
#              Player       Span  Matches  Innings  Not Out  Runs High Score  \
# 24  VG Kambli (IND)  1993-1995       17       21        1  1084        227
#
#     Average Ball Faced Strike Rate  100  50  0   4s  6s
# 24     54.2       1823       59.46    4   3  3  124   6

# %%
df[df["Player"]=="HC Brook (ENG)"]      #using and operator in this query and use two player names...
# Out:
#            Player       Span  Matches  Innings  Not Out  Runs High Score  \
# 1  HC Brook (ENG)  2022-2023       12       20        1  1181        186
#
#    Average Ball Faced Strike Rate  100  50  0   4s  6s
# 1    62.15       1287       91.76    4   7  1  141  23

# %%
df.drop_duplicates()      #if want to save then use implace=true.
# Out:
#                Player       Span  Matches  Innings  Not Out  Runs High Score  \
# 0    DG Bradman (AUS)  1928-1948       52       80       10  6996        334
# 1      HC Brook (ENG)  2022-2023       12       20        1  1181        186
# 2      AC Voges (AUS)  2015-2016       20       31        7  1485       269*
# 3     RG Pollock (SA)  1963-1970       23       41        4  2256        274
# 5     GA Headley (WI)  1930-1954       22       40        4  2190       270*
# ..                ...        ...      ...      ...      ...   ...        ...
# 61   KD Walters (AUS)  1965-1981       74      125       14  5357        250
# 62  GC Smith (ICC/SA)  2002-2014      117      205       13  9265        277
# 63  WH Ponsford (AUS)  1924-1934       29       48        4  2122        266
# 64    SJ McCabe (AUS)  1930-1938       39       62        5  2748        232
# 65   DR Jardine (ENG)  1928-1934       22       33        6  1296        127
#
# ...

# %%
df.head()
# Out:
#              Player       Span  Matches  Innings  Not Out  Runs High Score  \
# 0  DG Bradman (AUS)  1928-1948       52       80       10  6996        334
# 1    HC Brook (ENG)  2022-2023       12       20        1  1181        186
# 2    AC Voges (AUS)  2015-2016       20       31        7  1485       269*
# 3   RG Pollock (SA)  1963-1970       23       41        4  2256        274
# 4   RG Pollock (SA)  1963-1970       23       41        4  2256        274
#
#    Average Ball Faced Strike Rate  100  50  0   4s  6s
# 0    99.94      9800+       58.60   29  13  7  626   6
# 1    62.15       1287       91.76    4   7  1  141  23
# 2    61.87       2667       55.68    5   4  2  186   5
# 3    60.97      1707+       54.48    7  11  1  246  11
# 4    60.97      1707+       54.48    7  11  1  246  11

# %%
df.describe()
# Out:
#           Matches     Innings    Not Out          Runs    Average        100  \
# count   66.000000   66.000000  66.000000     66.000000  66.000000  66.000000
# mean    79.015152  134.000000  13.757576   6383.803030  53.931818  19.318182
# std     50.848037   86.530919  10.968571   4045.919894   7.052478  12.456891
# min     12.000000   20.000000   1.000000    990.000000  48.000000   1.000000
# 25%     24.500000   42.750000   5.000000   2256.000000  49.660000   7.000000
# 50%     79.000000  134.500000  12.000000   6520.500000  52.170000  19.500000
# 75%    117.750000  196.250000  18.750000   8831.500000  56.677500  29.000000
# max    200.000000  329.000000  49.000000  15921.000000  99.940000  51.000000
#
#               50          0           4s         6s
# count  66.000000  66.000000    66.000000  66.000000
# mean   28.287879   7.696970   653.469697  27.121212
# std    18.670227   5.496767   523.855506  26.548948
# min     3.000000   1.000000    37.000000   0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Player       66 non-null     object
#  1   Span         66 non-null     object
#  2   Matches      66 non-null     int64
#  3   Innings      66 non-null     int64
#  4   Not Out      66 non-null     int64
#  5   Runs         66 non-null     int64
#  6   High Score   66 non-null     object
#  7   Average      66 non-null     float64
#  8   Ball Faced   66 non-null     object
#  9   Strike Rate  66 non-null     object
#  10  100          66 non-null     int64
#  11  50           66 non-null     int64
#  12  0            66 non-null     int64
#  13  4s           66 non-null     int64
#  14  6s           66 non-null     int64
# dtypes: float64(1), int64(9), object(5)
# memory usage: 7.9+ KB

# %%
df.head(2)
# Out:
#              Player       Span  Matches  Innings  Not Out  Runs High Score  \
# 0  DG Bradman (AUS)  1928-1948       52       80       10  6996        334
# 1    HC Brook (ENG)  2022-2023       12       20        1  1181        186
#
#    Average Ball Faced Strike Rate  100  50  0   4s  6s
# 0    99.94      9800+       58.60   29  13  7  626   6
# 1    62.15       1287       91.76    4   7  1  141  23

# %%
df["Player"]
# Out:
# 0      DG Bradman (AUS)
# 1        HC Brook (ENG)
# 2        AC Voges (AUS)
# 3       RG Pollock (SA)
# 4       RG Pollock (SA)
#             ...
# 61     KD Walters (AUS)
# 62    GC Smith (ICC/SA)
# 63    WH Ponsford (AUS)
# 64      SJ McCabe (AUS)
# 65     DR Jardine (ENG)
# Name: Player, Length: 66, dtype: object

# %%
df["Player"].str.split('(')
# Out:
# 0      [DG Bradman , AUS)]
# 1        [HC Brook , ENG)]
# 2        [AC Voges , AUS)]
# 3       [RG Pollock , SA)]
# 4       [RG Pollock , SA)]
#               ...
# 61     [KD Walters , AUS)]
# 62    [GC Smith , ICC/SA)]
# 63    [WH Ponsford , AUS)]
# 64      [SJ McCabe , AUS)]
# 65     [DR Jardine , ENG)]
# Name: Player, Length: 66, dtype: object

# %%
x=df["Player"].str.split('(')

# %%
x[0][1]
# Out:
# 'AUS)'

# %%
x[0][1].split(")")
# Out:
# ['AUS', '']

# %%
x[0][1].split(")")[0]
# Out:
# 'AUS'

# %%
a=x[0][1].split(")")[0]

# %%
a
# Out:
# 'AUS'

# %%
df["Player"].str.split("(").str[1]
# Out:
# 0        AUS)
# 1        ENG)
# 2        AUS)
# 3         SA)
# 4         SA)
#        ...
# 61       AUS)
# 62    ICC/SA)
# 63       AUS)
# 64       AUS)
# 65       ENG)
# Name: Player, Length: 66, dtype: object

# %%
df["Player"].str.split("(").str[1].str.split("(")
# Out:
# 0        [AUS)]
# 1        [ENG)]
# 2        [AUS)]
# 3         [SA)]
# 4         [SA)]
#         ...
# 61       [AUS)]
# 62    [ICC/SA)]
# 63       [AUS)]
# 64       [AUS)]
# 65       [ENG)]
# Name: Player, Length: 66, dtype: object

# %%
df["Player"].str.split("(").str[1].str.split(")").str[0]
# Out:
# 0        AUS
# 1        ENG
# 2        AUS
# 3         SA
# 4         SA
#        ...
# 61       AUS
# 62    ICC/SA
# 63       AUS
# 64       AUS
# 65       ENG
# Name: Player, Length: 66, dtype: object

# %%
df["Country"]=df["Player"].str.split("(").str[1].str.split(")").str[0]

# %%
df.head()
# Out:
#              Player       Span  Matches  Innings  Not Out  Runs High Score  \
# 0  DG Bradman (AUS)  1928-1948       52       80       10  6996        334
# 1    HC Brook (ENG)  2022-2023       12       20        1  1181        186
# 2    AC Voges (AUS)  2015-2016       20       31        7  1485       269*
# 3   RG Pollock (SA)  1963-1970       23       41        4  2256        274
# 4   RG Pollock (SA)  1963-1970       23       41        4  2256        274
#
#    Average Ball Faced Strike Rate  100  50  0   4s  6s Country
# 0    99.94      9800+       58.60   29  13  7  626   6     AUS
# 1    62.15       1287       91.76    4   7  1  141  23     ENG
# 2    61.87       2667       55.68    5   4  2  186   5     AUS
# 3    60.97      1707+       54.48    7  11  1  246  11      SA
# 4    60.97      1707+       54.48    7  11  1  246  11      SA

# %%
df["Player"].str.split("(").str[0]
# Out:
# 0      DG Bradman
# 1        HC Brook
# 2        AC Voges
# 3      RG Pollock
# 4      RG Pollock
#           ...
# 61     KD Walters
# 62       GC Smith
# 63    WH Ponsford
# 64      SJ McCabe
# 65     DR Jardine
# Name: Player, Length: 66, dtype: object

# %%
df["Player"].str.split("(").str[0].str.strip()
# Out:
# 0      DG Bradman
# 1        HC Brook
# 2        AC Voges
# 3      RG Pollock
# 4      RG Pollock
#          ...
# 61     KD Walters
# 62       GC Smith
# 63    WH Ponsford
# 64      SJ McCabe
# 65     DR Jardine
# Name: Player, Length: 66, dtype: object

# %%
df["Player"]=df["Player"].str.split("(").str[0].str.strip()

# %%
df.head()
# Out:
#        Player       Span  Matches  Innings  Not Out  Runs High Score  Average  \
# 0  DG Bradman  1928-1948       52       80       10  6996        334    99.94
# 1    HC Brook  2022-2023       12       20        1  1181        186    62.15
# 2    AC Voges  2015-2016       20       31        7  1485       269*    61.87
# 3  RG Pollock  1963-1970       23       41        4  2256        274    60.97
# 4  RG Pollock  1963-1970       23       41        4  2256        274    60.97
#
#   Ball Faced Strike Rate  100  50  0   4s  6s Country
# 0      9800+       58.60   29  13  7  626   6     AUS
# 1       1287       91.76    4   7  1  141  23     ENG
# 2       2667       55.68    5   4  2  186   5     AUS
# 3      1707+       54.48    7  11  1  246  11      SA
# 4      1707+       54.48    7  11  1  246  11      SA

# %%
df["Span"]
# Out:
# 0     1928-1948
# 1     2022-2023
# 2     2015-2016
# 3     1963-1970
# 4     1963-1970
#         ...
# 61    1965-1981
# 62    2002-2014
# 63    1924-1934
# 64    1930-1938
# 65    1928-1934
# Name: Span, Length: 66, dtype: object

# %%
df["Span"].str.split("-")
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1963, 1970]
#           ...
# 61    [1965, 1981]
# 62    [2002, 2014]
# 63    [1924, 1934]
# 64    [1930, 1938]
# 65    [1928, 1934]
# Name: Span, Length: 66, dtype: object

# %%
df["Span"].str.split("-").str[0]
# Out:
# 0     1928
# 1     2022
# 2     2015
# 3     1963
# 4     1963
#       ...
# 61    1965
# 62    2002
# 63    1924
# 64    1930
# 65    1928
# Name: Span, Length: 66, dtype: object

# %%
df["Span"].str.split("-").str[1]
# Out:
# 0     1948
# 1     2023
# 2     2016
# 3     1970
# 4     1970
#       ...
# 61    1981
# 62    2014
# 63    1934
# 64    1938
# 65    1934
# Name: Span, Length: 66, dtype: object

# %%
df["Debut year"]=df["Span"].str.split("-").str[0]

# %%
df["Ending Year*"]=df["Span"].str.split("-").str[1]

# %%
df.head(2)
# Out:
#        Player       Span  Matches  Innings  Not Out  Runs High Score  Average  \
# 0  DG Bradman  1928-1948       52       80       10  6996        334    99.94
# 1    HC Brook  2022-2023       12       20        1  1181        186    62.15
#
#   Ball Faced Strike Rate  100  50  0   4s  6s Country Debut year Ending Year*
# 0      9800+       58.60   29  13  7  626   6     AUS       1928         1948
# 1       1287       91.76    4   7  1  141  23     ENG       2022         2023

# %%
df.drop("Span",axis=1,inplace=True)

# %%
df.head(2)
# Out:
#        Player  Matches  Innings  Not Out  Runs High Score  Average Ball Faced  \
# 0  DG Bradman       52       80       10  6996        334    99.94      9800+
# 1    HC Brook       12       20        1  1181        186    62.15       1287
#
#   Strike Rate  100  50  0   4s  6s Country Debut year Ending Year*
# 0       58.60   29  13  7  626   6     AUS       1928         1948
# 1       91.76    4   7  1  141  23     ENG       2022         2023
